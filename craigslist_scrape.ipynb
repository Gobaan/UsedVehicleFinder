# %% [markdown]
# ## Overview
# In this notebook, I'll show you how to make a simple query on Craigslist using some nifty python modules. You can take advantage of all the structure data that exists on webpages to collect interesting datasets.

# %%
import time
import json
import bs4
import requests
from time import gmtime, strftime
import itertools
import pandas
import os.path
# %pylab
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
if not os.path.exists('vans.json'):
    with open('vans.json', 'w') as fp:
        pass

# %%
json.dumps({1:2, 3:4, "hello": "<br>\n\n<br>"})
# Out:
# '{"1": 2, "3": 4, "hello": "<br>\\n\\n<br>"}'

# %% [markdown]
# First we need to figure out how to submit a query to Craigslist. As with many websites, one way you can do this is simply by constructing the proper URL and sending it to Craigslist. Here's a sample URL that is returned after manually typing in a search to Craigslist:
# > `http://sfbay.craigslist.org/search/eby/apa?bedrooms=1&pets_cat=1&pets_dog=1&is_furnished=1`
#
# This is actually two separate things. The first tells craigslist what kind of thing we're searching for:
#
# > `http://sfbay.craigslist.org/search/eby/apa` says we're searching in the sfbay area (`sfbay`) for apartments (`apa`) in the east bay (`eby`).
#
# The second part contains the parameters that we pass to the search:
#
# > `?bedrooms=1&pets_cat=1&pets_dog=1&is_furnished=1` says we want 1+ bedrooms, cats allowed, dogs allowed, and furnished apartments. You can manually change these fields in order to create new queries.
#
# ## Getting a single posting
#
# So, we'll use this knowledge to send some custom URLs to Craigslist. We'll do this using the `requests` python module, which is really useful for querying websites.

# %%
import requests

# %% [markdown]
# In internet lingo, we're posting a `get` requests to the website, which simply says that we'd like to get some information from the Craigslist website.  With requests, we can easily create a dictionary that specifies parameters in the URL:

# %%
url_base = '%s/search/eby/cta' % domain
params = dict(max_price=15000, max_auto_miles=400000, auto_bodytype=[12], query=["dodge ram van"])
rsp = requests.get(url_base, params=params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4e1e1cdeae06> in <module>()
# ----> 1 url_base = '%s/search/eby/cta' % domain
#       2 params = dict(max_price=15000, max_auto_miles=400000, auto_bodytype=[12], query=["dodge ram van"])
#       3 rsp = requests.get(url_base, params=params)
#
# NameError: name 'domain' is not defined

# %%
# Note that requests automatically created the right URL:
print(rsp.url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-804dbac8c357> in <module>()
#       1 # Note that requests automatically created the right URL:
# ----> 2 print(rsp.url)
#
# NameError: name 'rsp' is not defined

# %%
# We can access the content of the response that Craigslist sent back here:
print(rsp.text[:500])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-38703d8f6705> in <module>()
#       1 # We can access the content of the response that Craigslist sent back here:
# ----> 2 print(rsp.text[:500])
#
# NameError: name 'rsp' is not defined

# %% [markdown]
# Wow, that's a lot of code. Remember, websites serve HTML documents, and usually your browser will automatically render this into a nice webpage for you. Since we're doing this with python, we get back the raw text. This is really useful, but how can we possibly parse it all?
#
# For this, we'll turn to another great package, BeautifulSoup:

# %%
import bs4


# BS4 can quickly parse our text, make sure to tell it that you're giving html
html = bs4(rsp.text, 'html.parser')

# BS makes it easy to look through a document
print(html.prettify()[:1000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f863a60f1d92> in <module>()
#       3
#       4 # BS4 can quickly parse our text, make sure to tell it that you're giving html
# ----> 5 html = bs4(rsp.text, 'html.parser')
#       6
#       7 # BS makes it easy to look through a document
#
# NameError: name 'rsp' is not defined

# %% [markdown]
# Beautiful soup lets us quickly search through an HTML document. We can pull out whatever information we want.
#
# Scanning through this text, we see a common structure repeated `<p class="row">`. This seems to be the container that has information for a single apartment.
#
# In BeautifulSoup, we can quickly get all instances of this container:

# %%
def search_cars(city, car):
    domain = "http://%s.craigslist.ca" % city
    url_base = '%s/search/eby/cta' % domain
    params = dict(max_price=15000, max_auto_miles=400000, auto_bodytype=[12], query=[car])
    try:
        rsp = requests.get(url_base, params=params)
    except:
        print (url_base)
        rsp = DummyResponse()
    return extract_vans(rsp, domain)

def search_rvs(city):
    domain = "http://%s.craigslist.ca" % city
    url_base = '%s/search/eby/rva' % domain
    params = dict(max_price=15000, max_auto_miles=400000, query=["van"])
    try:
        rsp = requests.get(url_base, params=params)
    except:
        print (url_base)
        rsp = DummyResponse()
    return extract_vans(rsp, domain)

def extract_vans(rsp, domain):
    def startsWithRds(x): return x.startswith('/') and x.endswith('.html')
    html = bs4.BeautifulSoup(rsp.text, 'html.parser').find('div', {'class':'rows'})
    print (domain)
    local = set()
    expanded = set()
    after = False
    for child in html.children:
        if not child.name: continue
        after = after or child.name == "h4"
        van = child.find_all('a', href=startsWithRds)
        if not van: continue
        site = "%s%s" % (domain, van[0]['href'])
        if after: expanded.add(site)
        else: local.add(site)
        
        
    time.sleep(5)
    return rsp, local, expanded

class DummyResponse(object):
    def __init__(self):
        self.text = "<html><div class='rows'/></html>"


print (extract_vans(DummyResponse(), "www.google.com"))
# Out:
# www.google.com
# (<__main__.DummyResponse object at 0x1114ef0f0>, set(), set())

# %%
rsp, local_rvs, expanded_rvs = search_rvs("vancouver")

# %%
rsp, local, expanded = search_cars("calgary", "dodge")

# %%
print (rsp.url)
print (local)
print (expanded)
for rv in local_rvs: print (rv)
print ('\n')
for rv in expanded_rvs: print (rv)
# Out:
# http://calgary.craigslist.ca/search/eby/cta?max_auto_miles=400000&query=dodge&max_price=15000&auto_bodytype=12
# set()
# {'http://calgary.craigslist.ca/cto/5745963333.html', 'http://calgary.craigslist.ca/cto/5740397391.html', 'http://calgary.craigslist.ca/cto/5764708290.html', 'http://calgary.craigslist.ca/ctd/5778398674.html'}
#
#
# http://vancouver.craigslist.ca/van/rvs/5776253820.html
# http://vancouver.craigslist.ca/rds/rvs/5754582504.html
# http://vancouver.craigslist.ca/rds/rvs/5734806377.html
# http://vancouver.craigslist.ca/rds/rvs/5736290339.html
# http://vancouver.craigslist.ca/rds/rvs/5776006205.html
# http://vancouver.craigslist.ca/van/rvs/5752404962.html
# http://vancouver.craigslist.ca/van/rvs/5786078746.html
# http://vancouver.craigslist.ca/van/rvs/5729143985.html
# http://vancouver.craigslist.ca/van/rvs/5726700410.html
# http://vancouver.craigslist.ca/van/rvs/5783665897.html
# http://vancouver.craigslist.ca/van/rvs/5754818395.html

# %%
crawled_vans = set() 
with open('vans.json', 'r') as fp:
    for line in fp:
        posting = json.loads(line)
        crawled_vans.add(posting['url'])
print (crawled_vans)
# Out:
# {'http://seattle.craigslist.ca/tac/ctd/5778290580.html', 'http://abbotsford.craigslist.ca/cto/5765508132.html', 'http://seattle.craigslist.ca/see/cto/5771567112.html', 'http://whistler.craigslist.ca/rvs/5774337115.html', 'http://abbotsford.craigslist.ca/ctd/5779107359.html', 'http://vancouver.craigslist.ca/van/cto/5782397676.html', 'http://vancouver.craigslist.ca/rds/cto/5747659979.html', 'http://vancouver.craigslist.ca/van/cto/5786269504.html', 'http://vancouver.craigslist.ca/rds/ctd/5768579725.html', 'http://bellingham.craigslist.ca/ctd/5751530745.html', 'http://seattle.craigslist.ca/tac/cto/5737314404.html', 'http://seattle.craigslist.ca/tac/ctd/5751715989.html', 'http://seattle.craigslist.ca/tac/cto/5774219588.html', 'http://vancouver.craigslist.ca/rds/ctd/5735561127.html', 'http://seattle.craigslist.ca/sno/ctd/5737859118.html', 'http://seattle.craigslist.ca/see/cto/5738121271.html', 'http://seattle.craigslist.ca/see/cto/5778615723.html', 'http://seattle.craigslist.ca/tac/cto/5765846420.html', 'http://seattle.craigslist.ca/oly/cto/5783663567.html', 'http://vancouver.craigslist.ca/rds/rvs/5754582504.html', 'http://vancouver.craigslist.ca/rds/ctd/5730053756.html', 'http://seattle.craigslist.ca/est/cto/5770279709.html', 'http://seattle.craigslist.ca/see/ctd/5740379869.html', 'http://seattle.craigslist.ca/tac/rvd/5776292482.html', 'http://seattle.craigslist.ca/see/ctd/5762848326.html', 'http://vancouver.craigslist.ca/van/ctd/5778359958.html', 'http://seattle.craigslist.ca/skc/cto/5770784401.html', 'http://seattle.craigslist.ca/sno/cto/5766102061.html', 'http://seattle.craigslist.ca/see/cto/5774375527.html', 'http://seattle.craigslist.ca/tac/cto/5726711545.html', 'http://seattle.craigslist.ca/kit/rvd/5741774965.html', 'http://seattle.craigslist.ca/see/cto/5765884645.html', 'http://vancouver.craigslist.ca/bnc/ctd/5774763950.html', 'http://seattle.craigslist.ca/see/ctd/5760643836.html', 'http://seattle.craigslist.ca/see/cto/5779301464.html', 'http://edmonton.craigslist.ca/cto/5777896250.html', 'http://vancouver.craigslist.ca/bnc/ctd/5741691676.html', 'http://olympic.craigslist.ca/cto/5750896221.html', 'http://seattle.craigslist.ca/oly/cto/5751870529.html', 'http://calgary.craigslist.ca/cto/5775930045.html', 'http://vancouver.craigslist.ca/bnc/ctd/5789050672.html', 'http://seattle.craigslist.ca/sno/ctd/5782218532.html', 'http://vancouver.craigslist.ca/bnc/ctd/5790823235.html', 'http://abbotsford.craigslist.ca/rvs/5719693092.html', 'http://seattle.craigslist.ca/see/cto/5774888414.html', 'http://vancouver.craigslist.ca/bnc/cto/5765920661.html', 'http://vancouver.craigslist.ca/van/ctd/5791522016.html', 'http://vancouver.craigslist.ca/rds/cto/5790064686.html', 'http://seattle.craigslist.ca/see/cto/5747279723.html', 'http://vancouver.craigslist.ca/rds/ctd/5753304240.html', 'http://vancouver.craigslist.ca/bnc/ctd/5759406585.html', 'http://vancouver.craigslist.ca/rds/ctd/5777035890.html', 'http://bellingham.craigslist.ca/cto/5755318992.html', 'http://vancouver.craigslist.ca/rds/cto/5712122304.html', 'http://seattle.craigslist.ca/see/cto/5742324075.html', 'http://seattle.craigslist.ca/see/rvd/5711617627.html', 'http://seattle.craigslist.ca/est/ctd/5779143861.html', 'http://seattle.craigslist.ca/see/ctd/5779346283.html', 'http://vancouver.craigslist.ca/rds/ctd/5766079056.html', 'http://vancouver.craigslist.ca/bnc/ctd/5762612242.html', 'http://seattle.craigslist.ca/tac/ctd/5783372957.html', 'http://vancouver.craigslist.ca/rds/ctd/5766363743.html', 'http://abbotsford.craigslist.ca/ctd/5734622567.html', 'http://vancouver.craigslist.ca/pml/cto/5759178188.html', 'http://seattle.craigslist.ca/tac/ctd/5769501906.html', 'http://victoria.craigslist.ca/cto/5734170041.html', 'http://vancouver.craigslist.ca/bnc/cto/5700595191.html', 'http://vancouver.craigslist.ca/rds/ctd/5780811668.html', 'http://vancouver.craigslist.ca/rds/cto/5786072329.html', 'http://seattle.craigslist.ca/sno/cto/5742106431.html', 'http://seattle.craigslist.ca/skc/cto/5778243336.h ...

# %%
def extract_posting(city, query, posting_urls, expanded=False):
    for posting_url in posting_urls:
        if posting_url in crawled_vans: continue
        response = requests.get(posting_url)
        txt = bs4.BeautifulSoup(response.text, 'html.parser')
        cars = txt.findAll(attrs={'class': "row"})

        details = txt.find(attrs={'class': 'mapAndAttrs'}).findAll('span')
        details = [detail.text for detail in details]
        details[0] = "model: " + details[0]
        details = [detail.split(":") for detail in details]
        garbage = [detail[0] for detail in details if len(detail) == 1]
        details = {detail[0]:detail[1].strip() for detail in details if len(detail) == 2}
        
        images = txt.findAll("img")
        images = [image["src"].replace('50x50c', '600x450') for image in images]

        title = txt.find("span", {"id": "titletextonly"}).text
        price = txt.find("span", {"class": "price"}).text

        body = txt.find("section", {"id": "postingbody"})
        details['body'] = str(body)
        details['images'] = images
        details['garbage'] = garbage
        details['title'] = title
        details['price'] = price
        details['query'] = query
        details['city'] = city
        details['url'] = posting_url
        details['expanded'] = expanded
        details['date'] = strftime("%Y-%m-%d %H:%M:%S", gmtime())
        details['deadlink'] = False
        with open('vans.json', 'a') as fp:
            fp.write(json.dumps(details) + '\n')
            crawled_vans.add(posting_url)
        time.sleep(5)

def extract_postings(cities, cars):
    for city in cities:
        for car in cars:
            try:
                rsp, local, expanded = search_cars(city, car)
                extract_posting(city, car, local, False)
            except:
                pass
            
        try:    
            rsp, local, expanded = search_rvs(city)  
            extract_posting(city, "rv", local, False)
        except:
            pass
        
    for city in cities:
        for car in cars:
            try:
                rsp, local, expanded = search_cars(city, car)
                extract_posting(city, car, expanded, True)
            except:
                pass
        
        try:
            rsp, local, expanded = search_rvs(city)
            extract_posting(city, "rv", expanded, True)
        except: 
            pass

# %%
cities = ["vancouver", "bellingham", "comoxvalley", "abbotsford", "kamloops", "kelowna", 
          "moseslake", "nanaimo", "olympic", "seattle", "skagit", "sunshine", "victoria", 
          "wenatchee", "whistler", "yakima"]
cities += ["calgary", "edmonton", "ftmcmurray", "reddeer"]
cities = ["vancouver", "abbotsford", "whistler", "kamloops", "kelowna"]
cars = ["dodge ram van", "ford tuscany van", "food truck", "chevy express", "gmc savana", "ford econoline", 
        "ford e350", "ford transit", "cargo van" ]
extract_postings(cities, cars)

# %%
details

# %%
images = txt.findAll("img")
images = [image["src"].replace('50x50c', '600x450') for image in images]
for image in images:
    print(image)

# %%
title = txt.find("span", {"id": "titletextonly"}).text
price = txt.find("span", {"class": "price"}).text
print(title)
print(price)

# %%
with open('vans.json', 'r') as fp:
    vans = [json.loads(line) for line in fp]

# %%
with open('processed_vans.json', 'w') as fp:
    for van in vans:
        url = van['url']
        if ('deadlink' not in van or not van['deadlink']):
            try:
                text = requests.get(url).text
                van['deadlink'] = 'This posting has been deleted by its author' in text
            except:
                van['deadlink'] = False
            time.sleep(5)
        fp.write(json.dumps(van) + '\n')

# %%
vans[1]

# %%
import pandas

# %%
frame = pandas.DataFrame(vans)

# %%
frame['odometer'] = [int(value) for value in frame['odometer']]
frame['price'] = [int(value.replace('$', '')) for value in frame['price']]
frame['value'] = frame['price'] / frame['odometer']
frame = frame.drop_duplicates(subset=['price', 'title', 'odometer'])

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 521 entries, 0 to 771
# Data columns (total 25 columns):
# VIN                  148 non-null object
# body                 521 non-null object
# city                 521 non-null object
# condition            423 non-null object
# cylinders            435 non-null object
# date                 167 non-null object
# deadlink             521 non-null bool
# drive                421 non-null object
# expanded             521 non-null bool
# fuel                 521 non-null object
# garbage              521 non-null object
# images               521 non-null object
# model                521 non-null object
# odometer             521 non-null int64
# paint color          455 non-null object
# price                521 non-null int64
# query                521 non-null object
# size                 310 non-null object
# size / dimensions    19 non-null object
# title                521 non-null object
# title status         510 non-null object
# transmission         521 non-null object
# type                 466 non-null object
# url                  521 non-null object
# value                521 non-null float64
# dtypes: bool(2), float64(1), int64(2), object(20)
# memory usage: 98.7+ KB

# %%
import matplotlib.pyplot as plt

# %%
canadian_cities = ["vancouver", "abbotsford", "whistler", "kamloops", "kelowna"]
localonly = (frame['city'].isin(canadian_cities))
points = frame[localonly]

indices = {}
next_index = 0
for index, isLocal in zip(itertools.count(), localonly):
    if isLocal:
        indices[next_index] = index
        next_index += 1

# %%
def onclick(event):
    print (event.ind)
    for index in event.ind:
        point = points.xs(indices[index])
        print (point)
        print (point['url'])

def color(query):
    if query == "dodge ram van": return "red"
    elif query == "chevy express": return "black"
    elif query == "gmc savana": return "black"
    elif query == "cargo van": return "black"
    elif query == "ford transit": return "black"
    elif query.startswith("ford"): return "black"
    else: return "black"
    
        
fig = plt.figure(figsize=(20, 10))
print(sum(localonly))
colors = [color(query) for query in frame[localonly]["query"]]
plot = plt.scatter(points['odometer'], points['price'], color=colors, picker=True)  
cid = fig.canvas.mpl_connect('pick_event', onclick)
# Out:
# 271

# %%
rsp = requests.get('http://vancouver.craigslist.ca/rds/cto/5736427476.html')

# %%
pandas.set_option('display.expand_frame_repr', False)
pandas.set_option('display.max_colwidth', 300)
pandas.set_option('display.width', 1000)
pandas.set_option('display.max_rows', 1000)
points[['value', 'title', 'url', 'city', 'price', 'odometer']].sort_values('value', ascending=False)
# Out:
#          value                                                                   title                                                     url        city  price  odometer
# 712        inf                                                      Ford Econoline 350  http://vancouver.craigslist.ca/van/cto/5788231822.html   vancouver   3900         0
# 253        inf                                GREAT LITTLE TRAILER 1992 jAYCO LIKE NEW     http://abbotsford.craigslist.ca/rvs/5754596252.html  abbotsford   3800         0
# 14         inf                                         LIKE NEW 1992 JAYCO TENT TRILER  http://vancouver.craigslist.ca/rds/rvs/5754582504.html   vancouver   3800         0
# 473  28.000000                          Rare Duramax Diesel 2006 Chevrolet Express Van  http://vancouver.craigslist.ca/rds/cto/5772158485.html   vancouver   9800       350
# 199  18.435754                            2007 Dodge Caravan CV CARGO VAN ...AUTOMATIC  http://vancouver.craigslist.ca/van/cto/5766517749.html   vancouver   3300       179
# 207  16.894977                                       2007 Chevrolet uplander cargo van  http://vancouver.craigslist.ca/rch/cto/5769699632.html   vancouver   3700       219
# 724  12.690355                                                      99 Astro cargo van  http://vancouver.craigslist.ca/rds/cto/5790064686.html   vancouver   2500       197
# 133  10.778443                                         1994 Ford ecoline e150 work van  http://vancouver.craigslist.ca/rds/cto/5736427476.html   vancouver   1800       167
# 752   9.615385                                   2000 Chevrolet 1500 express cargo van  http://vancouver.craigslist.ca/nvn/cto/5798087173.html   vancouver   2500       260
# 150   3.215434                                                1996 FORD E250 ECONO VAN  http://vancouver.craigslist.ca/pml/cto/5720228945.html   vancouver   1000       311
# 9     0.240365                        Trade...2002 Yamaha Midnight Star 1600cc  low km  http://vancouver.craigslist.ca/van/rvs/5736257288.html   vancouver   5800     24130
# 719   0.158065                 2010 DODGE CARAVAN CARGO VAN ONLY 62000 KMS LADDER RACK  http://vancouver.craigslist.ca/van/ctd/5791522016.html   vancouver   9800     62000
# 8     0.134783                                                          Dodge Van 3500  http://vancouver.craigslist.ca/pml/cto/5698710907.html   vancouver   6200     46000
# 83    0.091077   1998 Chervrolet Express 3500 Turbo Diesel Box Cargo Van... 97,500 Km.  http://vancouver.craigslist.ca/rds/ctd/5725918536.html   vancouver   8880     97500
# 190   0.085112                                      2010 Dodge Grand Caravan Cargo Van  http://vancouver.craigslist.ca/rds/ctd/5768837533.html   vancouver   9500    111618
# 193   0.085112                                    ✔ 2010 Dodge Grand Caravan Cargo Van  http://vancouver.craigslist.ca/rds/ctd/5768516959.html   vancouver   9500    111618
# 655   0.083317                            2003 Chevrolet Astro Cargo Van - 120,*** KM!  http://vancouver.craigslist.ca/rch/ctd/5783592863.html   vancouver   9998    120000
# 769   0.082979                                               Ford Econoline Camper Van  http://vancouver.craigslist.ca/van/rvs/5799216591.html   vancouver   7800     94000
# 188   0.079002  2009 CHEVROLET UPLANDER CARGO VAN *ONLY 101K* 3.9L V6 *GREAT PRICE****  http://vancouver.craigslist.ca/van/ctd/5742223244.html   vancouver   7995    101200
# 258   0.079002  2009 CHEVROLET UPLANDER CARGO VAN *ONLY 101K* SHELVING & BULKHEAD*****        http://kelowna.craigslist.ca/ctd/5742223947.html     kelowna   7995    101200
# 713   0.073770                                                2004 Ford E250 Econoline  http://vancouver.craigslist.ca/van/cto/5792879871.html   vancouver   9000    122000
# 697   0.065909        2007 Dodge grand Caravan CV Cargo 4 dr auto must sdale this week  http://vancouver.craigslist.ca/bnc/ctd/5793174303.html   vancouver   5800     88000
# 45    0.065909        2005 Dodge grand Caravan CV Cargo 4 dr auto must sdale this week  http://vancouver.craigslist.ca/bnc/ctd/5762612242.html   vancouver   5800     88000
# 544   0.063953                                                 1976 dodge tradesman RV       http://whistler.craigslist.ca/rvs/5774337115.html    whistler   5500     86000
# 44    0.063478                ********** 2010 DODGE GRAND CARAVAN C/V CARGO **********  http://vancouver.craigslist.ca/bnc/ctd/5741691676.html   vancouver   7300    115000
# 164   0.062025                                     2005 Ford E-350 Passenger Cargo Van  http://vancouver.craigslist.ca/van/ctd/5765623388.html   vancouver   9800    158000
# 177   0.059825                                 2010 Ford Transit Connect XLT Van White  http://vancouver.craigslist.ca/rds/ctd/5767800118.html   vancouver   9900    165483
# 727   0.058511              U.S. 1984 Ford Fiesta camper with a shower and solar power  http://vancouver.craigslist.ca/van/rvs/5786078746.html   vancouver   5500     94000
# 25    0.057464                         2005 Chevrolet Express 3500 6L 8V 15 passengers  http://vancouver.craigslist.ca/bnc/cto/5752338711.html   vancouver   9900    172281
# 201   0.057025                                                   2001 Safari cargo van  http://vancouver.craigslist.ca/rds/cto/5769789511.html   vancouver   6900    121000
# 254   0.053333                                                           RV Camper Van     http://abbotsford.craigslist.ca/rvs/5719693092.html  abbotsford   4800     90000
# 162   0.053199                           Ford E-350 2006 Super Duty Cargo Van, fourgon  http://vancouver.craigslist.ca/van/cto/5730829672.html   vancouver   7900    148500
# 499   0.052941                                          1988 pleasureway motorhomr 21'     http://abbotsford.craigslist.ca/rvs/5770291986.html  abbotsford   9000    170000
# 260   0.049493                                                                     Van        http://kelowna.craigslist.ca/rvs/5761866332.html     kelowna   6500    131333
# 230   0.046633                    ✔ 1997 Chevrolet Express G1500 Conversion Van MARK 3     http://abbotsford.craigslist.ca/ctd/5755561538.html  abbotsford   6995    150000
# 229   0.046633                      1997 Chevrolet Express G1500 Conversion Van MARK 3     http://abbotsford.craigslist.ca/ctd/5755966617.html  abbotsford   6995    150000
# 709   0.046387                                          2005 GMC Savana Cargo Van 2500  http://vancouver.craigslist.ca/rds/ctd/5790871739.html   vancouver   8999    194000
# 117   0.046196                                                    2006 GMC Savana 2500  http://vancouver.craigslist.ca/pml/cto/5703596031.html   vancouver   8500    184000
# 90    0.045849                                 2007 Chevrolet Express 2 to choose from  http://vancouver.craigslist.ca/rds/ctd/5747096079.html   vancouver   9995    218000
# 18    0.045455                                   Camper Van Dodge Raised Roof No Leaks  http://vancouver.craigslist.ca/van/rvs/5752404962.html   vancouver   5000    110000
# 687   0.044500                               2008 Ford E150 Cargo Van, Great Condition  http://vancouver.craigslist.ca/bnc/cto/5793295080.html   vancouver   8900    200000
# 104   0.044395                                 2007 GMC Savana 2500 Cargo Van Extended  http://vancouver.craigslist.ca/rds/ctd/5754120511.html   vancouver   9900    223000
# 107   0.044395                              2007 GMC Savana 2500  Cargo Van, Extended,  http://vancouver.craigslist.ca/rds/ctd/5758934189.html   vancouver   9900    223000
# 4     0.043643  ***** 2000 DODGE RAM CAMPER VAN , DRIVES GREAT !!! , CALL JARRET *****  http://vancouver.craigslist.ca/rds/ctd/5686185289.html   vancouver   5499    126000
# 742   0.043500                               2008 Ford E150 Cargo Van, Great Condition  http://vancouver.craigslist.ca/bnc/cto/5797002091.html   vancouver   8700    200000
# 765   0.043011                                             Camper Van being sold as is  http://vancouver.craigslist.ca/van/rvs/5797282972.html   vancouver   8000    186000
# 566   0.041411                            1996 Ford E350 (15 Passenger) Club Wagon XLT  http://vancouver.craigslist.ca/rds/cto/5778597167.html   vancouver   7500    181112
# 41    0.041292                                                2005 Chevrolet Astro 2WD  http://vancouver.craigslist.ca/bnc/ctd/5759406585.html   vancouver   7500    181632
# 751   0.041053                                                 Chevy Express 2500  Van  http://vancouver.craigslist.ca/van/cto/5798563413.html   vancouver   7800    190000
# 113   0.040887                                                 Commercial Van for sale  http://vancouver.craigslist.ca/nvn/cto/5715475279.html   vancouver   8300    203000
# 720   0.039554                           1999 Chevrolet Astro Cargo Van only 101000kms  http://vancouver.craigslist.ca/pml/ctd/5789933013.html   vancouver   3995    101000
# 576   0.039164                                         2000 E350 ford 15 passenger Van     http://abbotsford.craigslist.ca/ctd/5780575915.html  abbotsford   7500    191500
# 134   0.039066                     2006 FORD ECONOLINE E-350 CUBE VAN ** ON PROPANE **  http://vancouver.craigslist.ca/rds/ctd/5721767096.html   vancouver   8900    227817
# 23    0.038922                                             19' Ford Econoline 150 1987  http://vancouver.craigslist.ca/van/rvs/5729143985.html   vancouver   6500    167000
# 462   0.038857               2001  Ford F250 XLT, Supercab, 4x4, canopy, 7.3 L diesel,  http://vancouver.craigslist.ca/bnc/ctd/5743513521.html   vancouver   6800    175000
# 103   0.038540                             2000 Chevrolet Express Cargo Van None White  http://vancouver.craigslist.ca/rds/ctd/5716787987.html   vancouver   4995    129604
# 76    0.038540                                        2000 Chevrolet Express Cargo Van  http://vancouver.craigslist.ca/pml/ctd/5707392678.html   vancouver   4995    129604
# 564   0.038043                                               2007 FORD E250 WORK TRUCK  http://vancouver.craigslist.ca/rds/cto/5779672786.html   vancouver   7000    184000
# 660   0.037931                                                   1987 Dodge Camper Van        http://kelowna.craigslist.ca/rvs/5784451315.html     kelowna   5500    145000
# 696   0.037817                                           2007 Chevrolet express G 2500  http://vancouver.craigslist.ca/bnc/ctd/5786498799.html   vancouver   7450    197000
# 619   0.037445                                                     carpet cleaning van  http://vancouver.craigslist.ca/van/cto/5782397676.html   vancouver   8500    227000
# 36    0.036822        2007 Ford Econoline E-250 Cargo Van Shelving Roof Rack BC0027560  http://vancouver.craigslist.ca/bnc/ctd/5704057474.html   vancouver   7640    207484
# 129   0.036703                          2003 FORD ECONOLINE E-350 EXT ** 7.3 DIESEL **  http://vancouver.craigslist.ca/rds/ctd/5728420528.html   vancouver   9900    269731
# 545   0.035758                             Camper Van - 1987 Ford Getaway - 165,000 km       http://whistler.craigslist.ca/rvs/5775722720.html    whistler   5900    165000
# 500   0.035714                                                 2007 Ford Econoline 250       http://kamloops.craigslist.ca/cto/5773980852.html    kamloops   7500    210000
# 75    0.035714                                   15 Passenger Van - Chevy Express 3500  http://vancouver.craigslist.ca/rds/cto/5752281225.html   vancouver   6500    182000
# 86    0.035652                                             2008 Chevrolet Express 2500  http://vancouver.craigslist.ca/rds/cto/5737723063.html   vancouver   8200    230000
# 733   0.035279                                           2007 Chevrolet express G 2500  http://vancouver.craigslist.ca/bnc/ctd/5794316942.html   vancouver   6950    197000
# 51    0.035235                                            ✔  2003 GMC Safari Cargo Van  http://vancouver.craigslist.ca/bnc/ctd/5721509442.html   vancouver   5990    170000
# 71    0.035020                                       2007 Chevrolet Express 1500 Cargo  http://vancouver.craigslist.ca/rds/ctd/5766363743.html   vancouver   8580    245000
# 100   0.035020                                     ✔ 2007 Chevrolet Express 1500 Cargo  http://vancouver.craigslist.ca/rds/ctd/5766319330.html   vancouver   8580    245000
# 46    0.034706                                        2004 HONDA ODYSSEY EX W/ LEATHER  http://vancouver.craigslist.ca/bnc/ctd/5729896560.html   vancouver   5900    170000
# 488   0.034118      2007 Dodge Grand Caravan Cargo Van, Shelves, 6 Month Free Warranty  http://vancouver.craigslist.ca/rds/ctd/5776318581.html   vancouver   5800    170000
# 28    0.033846                    2007 Chevrolet Express 2500 Series 3/4 Ton Cargo Van  http://vancouver.craigslist.ca/bnc/cto/5758749938.html   vancouver   8800    260000
# 168   0.033819                                                             ***SOLD ***  http://vancouver.craigslist.ca/rds/cto/5739255024.html   vancouver   8500    251341
# 52    0.033793                                            2007 Dodge Caravan Cargo Van  http://vancouver.craigslist.ca/bnc/ctd/5735505235.html   vancouver   4900    145000
# 192   0.033793                                            2007 Dodge Caravan cargo van  http://vancouver.craigslist.ca/rds/ctd/5729454842.html   vancouver   4900    145000
# 749   0.033793                 2007 Dodge Caravan Cargo Van  ***COMES WITH WARRANTY***  http://vancouver.craigslist.ca/bnc/ctd/5796047291.html   vancouver   4900    145000
# 84    0.033563                                   2006 Chevrolet 1500 Express cargo van  http://vancouver.craigslist.ca/rds/ctd/5757026878.html   vancouver   8900    265174
# 26    0.033389                                   2006 Chevrolet Express 1500 cargo van  http://vancouver.craigslist.ca/bnc/ctd/5757011019.html   vancouver   8900    266557
# 2     0.033333                                             1987 Chevy G20 Get-away Van  http://vancouver.craigslist.ca/bnc/rvs/5769261897.html   vancouver   4000    120000
# 741   0.032692                    2007 Chevrolet Express 2500 Series 3/4 Ton Cargo Van  http://vancouver.craigslist.ca/bnc/cto/5797453551.html   vancouver   8500    260000
# 173   0.032609                                           2005 Ford E350 Diesel 6.0 PSD  http://vancouver.craigslist.ca/van/cto/5761720145.html   vancouver   7500    230000
# 48    0.032143                           2008 Kia Rondo  7 Passengers 4 cylinders 2.4L  http://vancouver.craigslist.ca/bnc/ctd/5711568523.html   vancouver   6300    196000
# 766   0.031983                                    1988 Ford Econoline E-150 Camper Van  http://vancouver.craigslist.ca/van/rvs/5797833931.html   vancouver   5725    179000
# 1     0.031786                                                   Dodge Ram - cargo van  http://vancouver.craigslist.ca/bnc/cto/5700595191.html   vancouver   8900    280000
# 203   0.031410                                                Dodge Caravan- cargo van  http://vancouver.craigslist.ca/rds/cto/5766887205.html   vancouver   4900    156000
# 106   0.031294                                              2004 GMC Savana 2500 Cargo  http://vancouver.craigslist.ca/rds/ctd/5734697598.html   vancouver   7980    255000
# 32    0.030595  2005 Ford E-250 Cargo Van with Rear Shelving, 4.6L, 8 cylinder, 3 door  http://vancouver.craigslist.ca/bnc/ctd/5769212846.html   vancouver   6990    228465
# 186   0.030392  2001 GMC Safari Cargo Van, No Accidents ONLY 153,000km 1 YEAR WARRANTY  http://vancouver.craigslist.ca/rch/ctd/5769172769.html   vancouver   4650    153000
# 185   0.029064                                      2004 Chevrolet Astro Cargo Van 2WD  http://vancouver.craigslist.ca/rds/ctd/5767211591.html   vancouver   5900    203000
# 656   0.028235      2007 Dodge Grand Caravan Cargo Van, Shelves, 6 Month Free Warranty  http://vancouver.craigslist.ca/rds/ctd/5784642819.html   vancouver   4800    170000
# 732   0.028139                                1995 Ford ECONOLINE e350 Cube Van Diesel  http://vancouver.craigslist.ca/bnc/cto/5794542325.html   vancouver   6500    231000
# 128   0.027736                                             2006 GMC Savana G1500 Cargo  http://vancouver.craigslist.ca/rds/ctd/5766360766.html   vancouver   7350    265000
# 109   0.027736                                              2006 GMC SAVANA 1500 Cargo  http://vancouver.craigslist.ca/rds/ctd/5766380169.html   vancouver   7350    265000
# 96    0.027736                                       2006 Chevrolet Express 1500 Cargo  http://vancouver.craigslist.ca/rds/ctd/5758931911.html   vancouver   7350    265000
# 110   0.027736                                           ✔ 2006 GMC Savana G1500 Cargo  http://vancouver.craigslist.ca/rds/ctd/5766322637.html   vancouver   7350    265000
# 771   0.027586                                                         Baja Camper Van       http://whistler.craigslist.ca/rvs/5788269139.html    whistler   4000    145000
# 614   0.027159                               As is! 2000 Dodge Ram Van (Stock# 174912)  http://vancouver.craigslist.ca/rds/ctd/5782953938.html   vancouver   5900    217238
# 737   0.027143                                     1998 FORD ECONOLINE E250 ONLY 140 K  http://vancouver.craigslist.ca/van/ctd/5794537063.html   vancouver   3800    140000
# 39    0.026818                                               2004 GMC Safari Cargo Van  http://vancouver.craigslist.ca/bnc/ctd/5753187173.html   vancouver   5900    220000
# 568   0.026687                                                  2006 Freestar work van  http://vancouver.craigslist.ca/rds/cto/5747659979.html   vancouver   4350    163000
# 85    0.026507   2009 Chevrolet Express 3500 Passenger Cargo Van...Warranty Available.  http://vancouver.craigslist.ca/rds/ctd/5728219987.html   vancouver   9980    376500
# 490   0.026111  2001 GMC Safari Cargo Van, No Accidents ONLY 153,000km 1 YEAR WARRANTY  http://vancouver.craigslist.ca/rch/ctd/5777462759.html   vancouver   3995    153000
# 54    0.026106                                     2004 GMC Safari Cargo van Automatic  http://vancouver.craigslist.ca/bnc/ctd/5694520342.html   vancouver   5900    226000
# 659   0.025439                                                 2005 Ford E250 work van     http://abbotsford.craigslist.ca/cto/5777248424.html  abbotsford   5800    228000
# 55    0.025353                                                   2004 GMC Safari Cargo  http://vancouver.craigslist.ca/bnc/ctd/5768738893.html   vancouver   5900    232713
# 15    0.024933                     2010 Dodge Grand Caravan C/V with Camper Van option  http://vancouver.craigslist.ca/van/rvs/5761917255.html   vancouver   5800    232627
# 446   0.024775                                                Ford E-150 Van econoline       http://whistler.craigslist.ca/cto/5760439421.html    whistler   5500    222000
# 130   0.024740          2004 FORD ECONOLINE E-350 EXT CARGO VAN *** DRIVES PERFECT ***  http://vancouver.craigslist.ca/rds/ctd/5720338023.html   vancouver   5900    238479
# 156   0.024576                                               2002 FORD ECONOLINE  E250  http://vancouver.craigslist.ca/van/ctd/5715179624.html   vancouver   5800    236000
# 728   0.023605                                                      2005 chevy express     http://abbotsford.craigslist.ca/cto/5790767175.html  abbotsford   5500    233000
# 767   0.023364                                                            Truck 4 sale  http://vancouver.craigslist.ca/pml/rvs/5775821907.html   vancouver   5000    214000
# 174   0.023235                                                 1998 E350 ambulance,van  http://vancouver.craigslist.ca/rds/cto/5723484722.html   vancouver   7900    340000
# 768   0.023077                                       1984 Chevy Camper Van by Get Away  http://vancouver.craigslist.ca/nvn/rvs/5799175352.html   vancouver   3000    130000
# 21    0.023077                                              1981 Dodge Getaway Vanessa  http://vancouver.craigslist.ca/van/rvs/5754818395.html   vancouver   3000    130000
# 143   0.022665                                          For Sale - Cargo Van (1/2 Ton)  http://vancouver.craigslist.ca/rds/cto/5724287309.html   vancouver   4499    198500
# 194   0.022630                                       Astro Cargo Van 2004- Runs Well !  http://vancouver.craigslist.ca/nvn/cto/5768972204.html   vancouver   4990    220500
# 705   0.022500                                            2008 chevy express 1500  van  http://vancouver.craigslist.ca/rch/cto/5791635842.html   vancouver   6500    288888
# 16    0.021538                                 GMC Vandura motorhome vanguard security  http://vancouver.craigslist.ca/van/rvs/5758937501.html   vancouver   2800    130000
# 30    0.021296                                    Savana 2500 Van 2000 Window/Explorer  http://vancouver.craigslist.ca/bnc/cto/5717220478.html   vancouver   4600    216000
# 573   0.020854   2005 GMC WHITE SAFARI CARGO VAN - GREAT DEAL AND VALUE HERE!  2006 04  http://vancouver.craigslist.ca/pml/ctd/5778489237.html   vancouver   4900    234970
# 486   0.020363                                     Chevrolet Astro Cargo Van  225000KM  http://vancouver.craigslist.ca/nvn/cto/5774055163.html   vancouver   4490    220500
# 196   0.020075     2006 Dodge Caravan Cargo Van, Power Group, All White, Clean, Cheap!  http://vancouver.craigslist.ca/van/ctd/5761575957.html   vancouver   3995    199000
# 210   0.020064                          2006 Dodge Caravan Cargo Van *great condition*  http://vancouver.craigslist.ca/van/ctd/5758797088.html   vancouver   3995    199115
# 684   0.020000                                                          2005 Ford E250       http://whistler.craigslist.ca/cto/5775936283.html    whistler   4200    210000
# 649   0.020000                                         GMC SAVANA 2500 Cargo Van(2007)  http://vancouver.craigslist.ca/van/cto/5783234840.html   vancouver   6000    300000
# 167   0.019828                                                Ford 350 Cube Van:  SOLD  http://vancouver.craigslist.ca/van/cto/5739380616.html   vancouver   6900    348000
# 169   0.019444                                                     2004 Ford E-350 XLT  http://vancouver.craigslist.ca/van/cto/5767626988.html   vancouver   7000    360000
# 43    0.019417                                              2005 Chevy Astro Cargo Van  http://vancouver.craigslist.ca/bnc/cto/5747525417.html   vancouver   5495    283000
# 27    0.019039                                                CHEVRO EXPRESS 2500 4.8L  http://vancouver.craigslist.ca/bnc/cto/5678839416.html   vancouver   6000    315135
# 154   0.019003                                      1994 Ford Econoline Travel Van Red  http://vancouver.craigslist.ca/rds/ctd/5767758217.html   vancouver   3995    210233
# 135   0.019003                                          1994 Ford Econoline Travel Van  http://vancouver.craigslist.ca/pml/ctd/5707413352.html   vancouver   3995    210233
# 723   0.018845                                               2005 GMC Safari cargo van  http://vancouver.craigslist.ca/pml/cto/5791539788.html   vancouver   4975    264000
# 34    0.018771                                                2002 FORD E250 CARGO VAN  http://vancouver.craigslist.ca/bnc/cto/5757319858.html   vancouver   5500    293000
# 650   0.018652                                                      Ford E250 for sale  http://vancouver.craigslist.ca/van/cto/5783883995.html   vancouver   3500    187648
# 6     0.017964                                                           Dodge ram van  http://vancouver.craigslist.ca/pml/cto/5760217784.html   vancouver   3000    167000
# 213   0.017737                                                   Gmc safari cargo  van  http://vancouver.craigslist.ca/van/cto/5713063460.html   vancouver   4950    279072
# 563   0.016842                                                              GMC savana  http://vancouver.craigslist.ca/rds/cto/5779550378.html   vancouver   4800    285000
# 7     0.016667                                                      Dodge Ram Work Van  http://vancouver.craigslist.ca/pml/cto/5757082860.html   vancouver   3900    234000
# 153   0.016667                                                         2004 Ford E-250  http://vancouver.craigslist.ca/rds/cto/5763547578.html   vancouver   3000    180000
# 487   0.016471                                               2001 Dodge 2500 Cargo Van  http://vancouver.craigslist.ca/van/cto/5773045299.html   vancouver   2800    170000
# 496   0.015354                                                             78 Ford Van     http://abbotsford.craigslist.ca/cto/5775914757.html  abbotsford   1950    127000
# 40    0.015000                                                    1999 Chevrolet Astro  http://vancouver.craigslist.ca/bnc/cto/5764197752.html   vancouver   3000    200000
# 708   0.014950                                        2001 GMC Savana 15 Passenger Van  http://vancouver.craigslist.ca/van/cto/5786833916.html   vancouver   4500    301000
# 577   0.014706                                              2002 Chevy Astro Cargo Van     http://abbotsford.craigslist.ca/cto/5780685270.html  abbotsford   3500    238000
# 3     0.013725                                               Dodge RAM B250 Camper Van  http://vancouver.craigslist.ca/rds/cto/5732424733.html   vancouver   3500    255000
# 706   0.012837                                                   1999 2500G Savana van  http://vancouver.craigslist.ca/rds/cto/5786798885.html   vancouver   2650    206435
# 493   0.012658                                                        79 Dodge Class B  http://vancouver.craigslist.ca/rds/rvs/5776006205.html   vancouver   1000     79000
# 700   0.012609                                                1987 Dodge Ram Travelvan  http://vancouver.craigslist.ca/van/cto/5792863147.html   vancouver   2900    230000
# 606   0.012537                                                2001 Ford E250 Cargo Van  http://vancouver.craigslist.ca/bnc/cto/5781673859.html   vancouver   4250    339000
# 711   0.012500                                                           1986 Ford van  http://vancouver.craigslist.ca/van/cto/5786269504.html   vancouver   4000    320000
# 10    0.011659                                               Camper Van + camping gear  http://vancouver.craigslist.ca/van/rvs/5745005856.html   vancouver   2390    205000
# 239   0.011345                                       2003 Ford 350 Econoline Cargo Van     http://abbotsford.craigslist.ca/cto/5765508132.html  abbotsford   2995    264000
# 658   0.010989                                                           Ford windstar  http://vancouver.craigslist.ca/van/rvs/5783665897.html   vancouver   2000    182000
# 735   0.010830                                                  2002 CHEVROLET EXPRESS  http://vancouver.craigslist.ca/van/ctd/5794448842.html   vancouver   3250    300100
# 565   0.010638                                      1990 Ford Van with Wheelchair Lift  http://vancouver.craigslist.ca/nvn/cto/5780788642.html   vancouver   1500    141000
# 574   0.010156                                        DODGE RAM VAN B250 LE Camper Van     http://abbotsford.craigslist.ca/cto/5780898768.html  abbotsford   2600    256000
# 5     0.009857                                                     1994 Dodge RAM 250B  http://vancouver.craigslist.ca/rds/cto/5762023039.html   vancouver   2950    299289
# 482   0.009610                                              1996 Ford E350 Super Wagon  http://vancouver.craigslist.ca/rds/cto/5775926669.html   vancouver   3000    312166
# 497   0.009610                                                1996 Ford 350 Club Wagon     http://abbotsford.craigslist.ca/cto/5758891988.html  abbotsford   3000    312166
# 238   0.009474                                                      2002 Ford e250 cng     http://abbotsford.craigslist.ca/cto/5769344783.html  abbotsford   1800    190000
# 255   0.009274                                              1989 Ford E-350 Club Wagon       http://kamloops.craigslist.ca/cto/5736060474.html    kamloops   2300    248000
# 115   0.009072                                            1998 GMC Savana G2500 Cargo.  http://vancouver.craigslist.ca/rds/ctd/5725917211.html   vancouver   2980    328500
# 147   0.008993                                                1993 Ford 350 econoline.  http://vancouver.craigslist.ca/rds/cto/5734673350.html   vancouver   2500    278000
# 685   0.008526                                                Ford E 350 Passenger Van       http://whistler.craigslist.ca/cto/5785221759.html    whistler   2899    340000
# 257   0.008511                                   REDUCED -   1997 FORD E-250 CARGO VAN        http://kelowna.craigslist.ca/cto/5747369046.html     kelowna   2000    235000
# 695   0.008263                                                2000 Chevrolet Astro Van  http://vancouver.craigslist.ca/bnc/cto/5793304414.html   vancouver   1950    236000
# 757   0.008117                                                           Ford E150 Van  http://vancouver.craigslist.ca/pml/cto/5800138928.html   vancouver   1250    154000
# 617   0.007692                                          2004 Chevrolet Express 2500 V8  http://vancouver.craigslist.ca/rds/cto/5782361284.html   vancouver   2500    325000
# 256   0.007660                                               1997 FORD E-250 CARGO VAN        http://kelowna.craigslist.ca/cto/5705489008.html     kelowna   1800    235000
# 707   0.007643                                                   2006 gmc Savanah 3500  http://vancouver.craigslist.ca/rds/cto/5772348009.html   vancouver   2400    314000
# 195   0.007166                                    ✔ 2002 Chevrolet Astro Cargo Van 2WD  http://vancouver.craigslist.ca/rds/ctd/5756671907.html   vancouver   2250    314000
# 202   0.007166                                      2002 Chevrolet Astro Cargo Van 2WD  http://vancouver.craigslist.ca/rds/ctd/5756684346.html   vancouver   2250    314000
# 625   0.006780                                            2002 Ford Windstar Cargo Van  http://vancouver.craigslist.ca/rds/cto/5783036924.html   vancouver   1600    236000
# 47    0.006562                                                2001 gmc safari work van  http://vancouver.craigslist.ca/bnc/cto/5765920661.html   vancouver   2100    320000
# 761   0.006356                                            2002 Ford Windstar Cargo Van  http://vancouver.craigslist.ca/rds/cto/5796205756.html   vancouver   1500    236000
# 19    0.006291                                                    Gmc safari campervan  http://vancouver.craigslist.ca/van/rvs/5726700410.html   vancouver   1900    302000
# 692   0.006151                                         2004 white gmc Safari Cargo Van  http://vancouver.craigslist.ca/bnc/cto/5789190372.html   vancouver   1999    325000
# 731   0.005000                                                2003 GMC Savana work van  http://vancouver.craigslist.ca/bnc/cto/5794359292.html   vancouver   1500    300000
# 152   0.003636                               1994 ford econoline e150 cargo/travel van  http://vancouver.craigslist.ca/pml/cto/5759176485.html   vancouver    800    220000
# 136   0.003333                                                1994 Ford Econoline E150  http://vancouver.craigslist.ca/pml/cto/5759178188.html   vancouver    800    240000
# 498   0.002424                                                        GMC 91 CARGO VAN     http://abbotsford.craigslist.ca/cto/5777641722.html  abbotsford    800    330000

# %%
print (fig.canvas)
# Out:
# FigureCanvas object 0x10b5f1a48 wrapping NSView 0x7fe5f67d40b0

# %%
##################################################################
# IGNORE THIS PEW PEW PEW
##################################################################

# %% [markdown]
# Now let's look inside the values of a single apartment listing:

# %%
# We can see that there's a consistent structure to a listing.
# There is a 'time', a 'name', a 'housing' field with size/n_brs, etc.
this_appt = apts[15]
print(this_appt.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b82880a42248> in <module>()
#       1 # We can see that there's a consistent structure to a listing.
#       2 # There is a 'time', a 'name', a 'housing' field with size/n_brs, etc.
# ----> 3 this_appt = apts[15]
#       4 print(this_appt.prettify())
#
# NameError: name 'apts' is not defined

# %%
# So now we'll pull out a couple of things we might be interested in:
# It looks like "housing" contains size information. We'll pull that.
# Note that `findAll` returns a list, since there's only one entry in
# this HTML, we'll just pull the first item.
size = this_appt.findAll(attrs={'class': 'housing'})[0].text
print(size)

# %% [markdown]
# We can query split this into n_bedrooms and the size. However, note that sometimes one of these features might be missing. So we'll use an `if` statement to try and capture this variability:

# %%
def find_size_and_brs(size):
    split = size.strip('/- ').split(' - ')
    if len(split) == 2:
        n_brs = split[0].replace('br', '')
        this_size = split[1].replace('ft2', '')
    elif 'br' in split[0]:
        # It's the n_bedrooms
        n_brs = split[0].replace('br', '')
        this_size = np.nan
    elif 'ft2' in split[0]:
        # It's the size
        this_size = split[0].replace('ft2', '')
        n_brs = np.nan
    return float(this_size), float(n_brs)
this_size, n_brs = find_size_and_brs(size)

# %%
# Now we'll also pull a few other things:
this_time = this_appt.find('time')['datetime']
this_time = pd.to_datetime(this_time)
this_price = float(this_appt.find('span', {'class': 'price'}).text.strip('$'))
this_title = this_appt.find('a', attrs={'class': 'hdrlnk'}).text

# %%
# Now we've got the n_bedrooms, size, price, and time of listing
print('\n'.join([str(i) for i in [this_size, n_brs, this_time, this_price, this_title]]))

# %% [markdown]
# ## Querying lots of postings
#
# Cool - so now we've got some useful information about one listing. Now let's loop through many listings across several locations.
#
# It looks like there is a "city code" that distinguishes where you're searching. Here is a **not** up to date list: [link](https://sites.google.com/site/clsiteinfo/city-site-code-sort)
#
# Within the Bay Area, there are also a lot of sub-regional locations, which we'll define here, then loop through them all.
#
# Note that the `s` parameter tells Craiglist where to start in terms of the number of results given back. E.g., if s==100, then it starts at the 100th entry.

# %%
loc_prefixes = ['eby', 'nby', 'sfc', 'sby', 'scz']

# %% [markdown]
# We'll define a few helper functions to handle edge cases and make sure that we don't get any errors.

# %%
def find_prices(results):
    prices = []
    for rw in results:
        price = rw.find('span', {'class': 'price'})
        if price is not None:
            price = float(price.text.strip('$'))
        else:
            price = np.nan
        prices.append(price)
    return prices

def find_times(results):
    times = []
    for rw in apts:
        if time is not None:
            time = time['datetime']
            time = pd.to_datetime(time)
        else:
            time = np.nan
        times.append(time)
    return times

# %% [markdown]
# Now we're ready to go. We'll loop through all of our locations, and pull a number of entries for each one. We'll use a pandas dataframe to store everything, because this will be useful for future analysis.
#
# **Note** - Craigslist won't take kindly to you querying their server a bunch of times at once. Make sure not to pull too much data too quickly. Another option is to add a delay to each loop iteration. Otherwise your IP might get banned.

# %%
# Now loop through all of this and store the results
results = []  # We'll store the data here
# Careful with this...too many queries == your IP gets banned temporarily
search_indices = np.arange(0, 300, 100)
for loc in loc_prefixes:
    print loc
    for i in search_indices:
        url = 'http://sfbay.craigslist.org/search/{0}/apa'.format(loc)
        resp = requests.get(url, params={'bedrooms': 1, 's': i})
        txt = bs4(resp.text, 'html.parser')
        apts = txt.findAll(attrs={'class': "row"})
        
        # Find the size of all entries
        size_text = [rw.findAll(attrs={'class': 'housing'})[0].text for rw in apts]
        sizes_brs = [find_size_and_brs(stxt) for stxt in size_text]
        sizes, n_brs = zip(*sizes_brs)  # This unzips into 2 vectors
     
        # Find the title and link
        title = [rw.find('a', attrs={'class': 'hdrlnk'}).text for rw in apts]
        links = [rw.find('a', attrs={'class': 'hdrlnk'})['href'] for rw in apts]
        
        # Find the time
        time = [pd.to_datetime(rw.find('time')['datetime']) for rw in apts]
        price = find_prices(apts)
        
        # We'll create a dataframe to store all the data
        data = np.array([time, price, sizes, n_brs, title, links])
        col_names = ['time', 'price', 'size', 'brs', 'title', 'link']
        df = pd.DataFrame(data.T, columns=col_names)
        df = df.set_index('time')
        
        # Add the location variable to all entries
        df['loc'] = loc
        results.append(df)
        
        
# Finally, concatenate all the results
results = pd.concat(results, axis=0)
# Out:
# eby
# nby
# sfc
# sby
# scz

# %%
# We'll make sure that the right columns are represented numerically:
results[['price', 'size', 'brs']] = results[['price', 'size', 'brs']].convert_objects(convert_numeric=True)

# %%
# And there you have it:
results.head()
# Out:
#                      price  size  brs  \
# time
# 2015-08-30 15:40:00   2187   610    1
# 2015-08-30 15:39:00   2600   580    1
# 2015-08-30 15:38:00   3775  1232    2
# 2015-08-30 15:31:00   3023  1133    2
# 2015-08-30 15:31:00   3100   NaN    3
#
#                                                                  title  \
# time
# 2015-08-30 15:40:00  UNIQUE LOFT! Vaulted ceilings! Granite & Stain...
# 2015-08-30 15:39:00   Elmwood - College Ave between Ashby and Alcatraz
# 2015-08-30 15:38:00       2 BEDROOM, 2 BATH CONDO AVAILABLE AT MERCER!
# 2015-08-30 15:31:00  Stunning. Spectacular. Sprawling. This 2x2 has...
# 2015-08-30 15:31:00  Well mainted Fremont home with upgrades for a ...
#
#                                          link  loc
# time
# 2015-08-30 15:40:00  /eby/apa/5198406276.html  eby
# 2015-08-30 15:39:00  /eby/apa/5198403987.html  eby
# 2015-08-30 15:38:00  /eby/apa/5198395321.html  eby
# 2015-08-30 15:31:00  /eby/apa/5198383076.html  eby
# 2015-08-30 15:31:00  /eby/apa/5183531302.html  eby

# %%
ax = results.hist('price', bins=np.arange(0, 10000, 100))[0, 0]
ax.set_title('Mother of god.', fontsize=20)
ax.set_xlabel('Price', fontsize=18)
ax.set_ylabel('Count', fontsize=18)

# %%
# Finally, we can save this data to a CSV to play around with it later.
# We'll have to remove some annoying characters first:
import string
use_chars = string.ascii_letters +\
    ''.join([str(i) for i in range(10)]) +\
    ' /\.'
results['title'] = results['title'].apply(
    lambda a: ''.join([i for i in a if i in use_chars]))

results.to_csv('../data/craigslist_results.csv')

# %% [markdown]
# ## RECAP
# To sum up what we just did:
#
# * We defined the ability to query a website using a custom URL. This is usually the same in structure for website, but the parameter names will be different.
# * We sent a `get` request to Craigslist using the `requests` module of python.
# * We parsed the response using `BeautifulSoup4`.
# * We then looped through a bunch of apartment listings, pulled some relevant data, and combined it all into a cleaned and usable dataframe with `pandas`.
#
# Next up I'll take a look at the data, and see if there's anything interesting to make of it.

# %% [markdown]
# ## Bonus - auto-emailing yourself w/ notifications
# A few people have asked me about using this kind of process to make a bot that scrapes craigslist periodically. This is actually quite simple, as it basically involves pulling the top listings from craigslist, checking this against an "old" list, and detecting if there's anything new that has popped up since the last time you checked.
#
# Here's a simple script that will get the job done. Once again, don't pull too much data at once, and don't query Craigslist too frequently, or you're gonna get banned.

# %%
# We'll use the gmail module (there really is a module for everything in python)
import gmail
import time

# %%
gm = gmail.GMail('my_username', 'my_password')
gm.connect()

# Define our URL and a query we want to post
base_url = 'http://sfbay.craigslist.org/'
url = base_url + 'search/eby/apa?nh=48&anh=49&nh=112&nh=58&nh=61&nh=62&nh=66&max_price=2200&bedrooms=1'

# This will remove weird characters that people put in titles like ****!***!!!
use_chars = string.ascii_letters + ''.join([str(i) for i in range(10)]) + ' '

# %%
link_list = []  # We'll store the data here
link_list_send = []  # This is a list of links to be sent
send_list = []  # This is what will actually be sent in the email

# Careful with this...too many queries == your IP gets banned temporarily
while True:
    resp = requests.get(url)
    txt = bs4(resp.text, 'html.parser')
    apts = txt.findAll(attrs={'class': "row"})
    
    # We're just going to pull the title and link
    for apt in apts:
        title = apt.find_all('a', attrs={'class': 'hdrlnk'})[0]
        name = ''.join([i for i in title.text if i in use_chars])
        link = title.attrs['href']
        if link not in link_list and link not in link_list_send:
            print('Found new listing')
            link_list_send.append(link)
            send_list.append(name + '  -  ' + base_url+link)
            
    # Flush the cache if we've found new entries
    if len(link_list_send) > 0:
        print('Sending mail!')
        msg = '\n'.join(send_list)
        m = email.message.Message()
        m.set_payload(msg)
        gm.send(m, ['recipient_email@mydomain.com'])
        link_list += link_list_send
        link_list_send = []
        send_list = []
    
    # Sleep a bit so CL doesn't ban us
    sleep_amt = np.random.randint(60, 120)
    time.sleep(sleep_amt)

# %% [markdown]
# And there you have it - your own little bot to keep you on the top of the rental market.
